# %%
import networkx as nx

from projects.analysis_of_unstructured_data.assignment_4.scraper import CoauthorGraph, get_groups_of_coauthors, get_site

# %%
soup = get_site()
graph = CoauthorGraph()

for group in get_groups_of_coauthors(soup):
    graph.add_coauthor_group(group)

# %%
graph.draw()

# %%
components = list(nx.connected_components(graph))

# %%
components
# Out:
# [{'A. Chechkin',
#   'A. Grzesiek',
#   'A. Janicki',
#   'A. Jurlewicz',
#   'A. Kumar',
#   'A. Makagon',
#   'A. Michalak',
#   'A. Misiorek',
#   'A. Puc',
#   'A. Stanislavsky',
#   'A. Weron',
#   'A. Wilkowska',
#   'A. Wylomanska',
#   'B. Kozlowska',
#   'B. Przybylowicz',
#   'D. Kucharczyk',
#   'D. Szarek',
#   'E. Broszkiewicz-Suwaj',
#   'E. Wojcik',
#   'G. Krzyzanowski',
#   'G. Kukla',
#   'G. Sikora',
#   'G. Zak',
#   'H. Loch',
#   'H. Loch-Olszewska',
#   'H. Woszczek',
#   'J. Adamska',
#   'J. Gajda',
#   'J. Gruszka',
#   'J. Hebda-Sobkowicz',
#   'J. Iwanik',
#   'J. Janczura',
#   'J. Nowicka',
#   'J. Nowicka-Zagrajek',
#   'J. Obuchowski',
#   'J. Slezak',
#   'J. Sokolowski',
#   'J. Szwabinski',
#   'J. Witulska',
#   'K. Burnecki',
#   'K. Gasior',
#   'K. Maraj',
#   'K. Maraj-Zygmat',
#   'K. Skowronek',
#   'L. Bielak',
#   'L. Plociniczak',
#   'M. Balcerek',
#   'M. Borgosz-Koczwara',
#   'M. Kozlowski',
#   'M. Magdziarz',
#   'M. Malek',
#   'M. Mrozinska',
#   'M. Muszkieta',
#   'M. Teuerle',
#   'P. Kowalek',
#   'P. Kruczek',
#   'P. Mista',
#   'P. Sztuba',
#   'P. Wilman',
#   'R. Poloczanski',
#   'R. Weron',
#   'S. Ondruszko',
#   'S. Orzel',
#   'S. Staskiewicz',
#   'T. Piesiewicz',
#   'T. Weron',
#   'T. Zorawik',
#   'W. Mydlarczyk',
#   'W. Nitka',
#   'W. Okrasinski',
#   'W. Zulawinski',
#   'Z. Michna',
#   'Z. Palmowski'},
#  {'A. Fulinski'},
#  {'J. Goncerzewicz'},
#  {'B. Stawiarski'},
#  {'M. Kotulski'}]
