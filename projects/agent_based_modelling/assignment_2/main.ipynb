# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

from projects.agent_based_modelling.assignment_2.game_of_life import GameOfLife

# %%
GameOfLife.from_path(Path(__name__).parent / "out").animate("test.gif")
